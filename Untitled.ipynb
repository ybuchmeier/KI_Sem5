# %%
class Node:
    def __init__(self, value, previous_node=None, next_node=None):
        self.value = value
        self.previous_node = previous_node
        self.next_node = next_node

# %%
class LinkedList:
    def __init__(self):
        self.first_node = None
        self.last_node = None
        self.size = 0
        
    def append(self, value):
        """Fügt am Ende der Liste ein neues Elemnt hinzu"""
        if self.first_node is None:
            self.first_node = Node(value, None)
            self.last_node = self.first_node
        else:
            self.last_node.next_node = Node(value, self.last_node)
            self.size += 1
        
    def insert(self, value, i):
        """Fügt an der Stelle i ein neues Element ein"""
        pass
    
    def pop(self, i=0):
        """Löscht und gibt das Element an der alten Stelle i zurück"""
        pass
    
    def get(self, i):
        """Gibt das Element an Stelle i zurück"""
        if i > __len__(self):
            raise IndexError
        current = self.first_node
        for _ in range(i):
            current = current.next_node
        return current.value
    
    def clear(self):
        """Leert die Liste"""
        self.first_node = None
        self.last_node = None
        self.size = 0
    
    def find(self, value):
        """Gibt den ersten Index """
        current = self.first_node
        for a in range(self.size):
            if current.value == value:
                return a
            else:
                current = current.next_node
            
    def count(self, value):
        current = self.first_node
        count = 0
        for _ in range(self.size):
            if current.value == value:
                count += 1
            else:
                current = current.next_node
        return count
        
        
    def sort(self):
        print("sort... still processing")
    pass

    def copy(self):
        copied_list = LinkedList()
        current = self.first_node
        for _ in range(self.size):
            copied_list.append(current)
            current = self.next_node
        return copied_list
        
    def __len__(self):
        return self.size
    
    def __repr__(self):
        current = self.first_node
        for _ in range(self.size):
            print("Node: " + str(current) + ", value: " + str(current.value))
            
        
    def __iter__(self):
        self.iter_current_node = first_node
        return self
    
    def __next__(self):
        result = self.iter_current_node
        if result is None:
            raise StopIteration
        self.iter_current_node = self.iter_current_node.next_node
        return result
    
    def __getitem__(self, i):
        return self.get(i)
    
    def __setitem__(self, i, value):
        self.get(i).value = value

# %%
liste = LinkedList()
liste.append(5)
liste.__repr__()
